# %%
# !unzip images.zip
# Out:
# Archive:  images.zip
#    creating: images/dogs/
#   inflating: images/dogs/10.jpg
#   inflating: images/dogs/12.jpg
#   inflating: images/dogs/13.jpg
#   inflating: images/dogs/15.jpg
#   inflating: images/dogs/2.jpg
#   inflating: images/dogs/4.jpg
#   inflating: images/dogs/5.jpg
#   inflating: images/dogs/7.jpg
#    creating: images/muffins/
#   inflating: images/muffins/1.jpg
#   inflating: images/muffins/11.jpg
#   inflating: images/muffins/14.jpg
#   inflating: images/muffins/16.jpg
#   inflating: images/muffins/3.jpg
#   inflating: images/muffins/6.jpg
#   inflating: images/muffins/8.jpg
#   inflating: images/muffins/9.jpg

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras import backend as K
import numpy as np
from keras.preprocessing import image
import os

# %%
img_wid, img_hei = 64, 64

train_data_dir = '/content/images/'

batch_size = 16
epochs = 10

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_wid, img_wid)
else:
    input_shape = (img_wid, img_hei, 3)


train_datagen = ImageDataGenerator(
    rescale = 1. /255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size = (img_wid, img_hei),
    color_mode = "rgb",
    batch_size = batch_size,
    class_mode = 'binary')
# Out:
# Found 16 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32,(3,3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

#model.summary()

model.add(Conv2D(32, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('softmax'))

model.summary()

model.compile(loss = 'binary_crossentropy',
             optimizer = 'adam',
             metrics = ['accuracy'])
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 62, 62, 32)        896
# _________________________________________________________________
# activation_21 (Activation)   (None, 62, 62, 32)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 29, 29, 32)        9248
# _________________________________________________________________
# activation_22 (Activation)   (None, 29, 29, 32)        0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 12, 12, 64)        18496
# _________________________________________________________________
# activation_23 (Activation)   (None, 12, 12, 64)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                147520
# _________________________________________________________________
# activation_24 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 65
# _________________________________________________________________
# activation_25 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 176,225
# Trainable params: 176,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit_generator(train_generator,
                    steps_per_epoch = 16/10,
                    epochs = epochs)
# Out:
# Epoch 1/10
# 2/1 [=====================================] - 0s 105ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 2/10
# 2/1 [=====================================] - 0s 112ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 3/10
# 2/1 [=====================================] - 0s 96ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 4/10
# 2/1 [=====================================] - 0s 99ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 5/10
# 2/1 [=====================================] - 0s 102ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 6/10
# 2/1 [=====================================] - 0s 98ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 7/10
# 2/1 [=====================================] - 0s 101ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 8/10
# 2/1 [=====================================] - 0s 96ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 9/10
# 2/1 [=====================================] - 0s 99ms/step - loss: 7.6666 - accuracy: 0.5000
# Epoch 10/10
# 2/1 [=====================================] - 0s 100ms/step - loss: 7.6666 - accuracy: 0.5000
